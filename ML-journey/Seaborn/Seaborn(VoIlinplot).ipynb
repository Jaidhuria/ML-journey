# %%
#volin plot
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#load dataset
y = sns.load_dataset("tips")
y
# sns.violinplot(x='day',y='total_bill',data = y)
# plt.show()
sns.violinplot(x="time",y='total_bill',data = y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#load dataset
y = sns.load_dataset("tips")
# y
sns.violinplot(x='day',y='total_bill',data = y,color="skyblue")
plt.show()
