# %%
# line graph
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Load the dataset
y_1 = sns.load_dataset("penguins")
# y_1 to look the data and it's parameter

sns.lineplot(x = "bill_depth_mm", y ="flipper_length_mm", data =y_1,color = "black")

# sns.lineplot(x = "bill_depth_mm", y ="flipper_length_mm", data =y_1,color = "black", hue = "sex", style = "sex", palette ='Accent',markers = ["o",">"](for points design))

plt.show()

# %%
# Bar graph
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
var =  sns.load_dataset("penguins")
# var
#var to read the description
sns.barplot(x="island",y="bill_length_mm", data =var,hue = "sex")
#sns.barplot(x="island",y="bill_length_mm", data =var,hue = "sex",orient="v/h (for changing its orientation),
#ERRWIDTH = ".."(TO INCREASE STRIP WIDTH), errcolor =".."("to change colour of strip"),dodge= false(graph superimpose each parameter),
# capsize = ".."("to up and down horizontal cap"),alpha=".."("for opacity"),order = order_1,hue_order=["female","male"]("to change the order of the graph parameter")

# plt.show()
# Out:
# <Axes: xlabel='island', ylabel='bill_length_mm'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
var =  sns.load_dataset("penguins")
# var
#var to read the description
sns.displot(var["bill_length_mm"],kde = True)
#kde mean it ad a line on the histogram
#log_scale change the value in log function

# plt.show()
