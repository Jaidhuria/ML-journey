# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)
     
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.293877 -2.770839  1.812377 -2.154426  1.442593       0
# 1 -1.029186  1.058281 -0.428412  1.893919  0.043444       1
# 2  1.951150  0.917034  1.266927  2.967839  2.825524       0
# 3  1.323699  0.327547  1.977374  0.789916  0.463645       1
# 4  0.283173  1.721956 -1.196834  3.256596 -1.190101       0
