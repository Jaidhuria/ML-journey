# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Coding\\machine learning\\CSV Files\\student_performance_analysis.csv")
df
# Out:
#     student_id  gender  hours_studied  attendance_percent  \
# 0            1  Female            6.3                  61
# 1            2    Male            7.6                  62
# 2            3  Female            8.9                  63
# 3            4    Male           10.2                  64
# 4            5  Female           11.5                  65
# 5            6    Male           12.8                  66
# 6            7  Female           14.1                  67
# 7            8    Male           15.4                  68
# 8            9  Female           16.7                  69
# 9           10    Male            5.0                  70
# 10          11  Female            6.3                  71
# 11          12    Male            7.6                  72
# 12          13  Female            8.9                  73
# 13          14    Male           10.2                  74
# 14          15  Female           11.5                  75
# ...

# %%
df.head()
# Out:
#    student_id  gender  hours_studied  attendance_percent  \
# 0           1  Female            6.3                  61
# 1           2    Male            7.6                  62
# 2           3  Female            8.9                  63
# 3           4    Male           10.2                  64
# 4           5  Female           11.5                  65
#
#    assignments_completed  test_score
# 0                      6        50.9
# 1                      7        51.8
# 2                      8        52.7
# 3                      9        53.6
# 4                     10        54.5

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    25
# Male      25
# Name: count, dtype: int64

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['hours_studied'].value_counts()
# Out:
# hours_studied
# 6.3     5
# 7.6     5
# 8.9     5
# 10.2    5
# 11.5    5
# 12.8    5
# 14.1    5
# 15.4    5
# 16.7    5
# 5.0     5
# Name: count, dtype: int64

# %%
pd.get_dummies(df,columns=['gender'])
# Out:
#     student_id  hours_studied  attendance_percent  assignments_completed  \
# 0            1            6.3                  61                      6
# 1            2            7.6                  62                      7
# 2            3            8.9                  63                      8
# 3            4           10.2                  64                      9
# 4            5           11.5                  65                     10
# 5            6           12.8                  66                     11
# 6            7           14.1                  67                     12
# 7            8           15.4                  68                     13
# 8            9           16.7                  69                     14
# 9           10            5.0                  70                      5
# 10          11            6.3                  71                      6
# 11          12            7.6                  72                      7
# ...
