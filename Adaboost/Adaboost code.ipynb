# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\jaidh\build\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\jaidh\build\lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\jaidh\build\lib\site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\jaidh\build\lib\site-packages (from mlxtend) (1.8.0)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\jaidh\build\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jaidh\build\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jaidh\build\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jaidh\build\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jaidh\build\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
# Installing collected packages: matplotlib, mlxtend
#
#   Attempting uninstall: matplotlib
#
#     Found existing installation: matplotlib 3.10.0
#
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#     Uninstalling matplotlib-3.10.0:
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.0
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    ---------------------------------------- 2/2 [mlxtend]
#
# Successfully installed matplotlib-3.10.9 mlxtend-0.24.0
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)

# %%
import pandas as pd
import numpy as np
from mlxtend.plotting import plot_decision_regions
# Out:
# C:\Users\jaidh\build\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.DataFrame()

# %%
df['X1'] = [1,2,3,4,5,6,6,7,9,9]
df['X2'] = [5,3,6,8,1,9,5,8,9,2]
df['label'] = [1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights'] = 1/df.shape[0]
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(max_depth=1)
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values
# Step 2 - Train 1st model
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf=dt1, legend=2)
# Out:
# <Axes: >

# %%
df['y_pred'] = dt1.predict(X)
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       1
# 3   4   8      1      0.1       1
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       1
# 6   6   5      0      0.1       1
# 7   7   8      1      0.1       1
# 8   9   9      0      0.1       1
# 9   9   2      0      0.1       0

# %%
def calculate_model_weight(error):

  return 0.5*np.log((1-error)/(error))
     
# Step 3 - calculate model weight
alpha1 = calculate_model_weight(0.3)
alpha1
# Out:
# np.float64(0.42364893019360184)

# %%
# Step 4 - Update weights
def update_row_weights(row,alpha=0.423):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)
df['updated_weights'] = df.apply(update_row_weights,axis=1)
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.065508
# 1   2   3      1      0.1       1         0.065508
# 2   3   6      0      0.1       1         0.152653
# 3   4   8      1      0.1       1         0.065508
# 4   5   1      0      0.1       0         0.065508
# 5   6   9      1      0.1       1         0.065508
# 6   6   5      0      0.1       1         0.152653
# 7   7   8      1      0.1       1         0.065508
# 8   9   9      0      0.1       1         0.152653
# 9   9   2      0      0.1       0         0.065508

# %%
df['nomalized_weights'] = df['updated_weights']/df['updated_weights'].sum()
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  nomalized_weights
# 0   1   5      1      0.1       1         0.065508           0.071475
# 1   2   3      1      0.1       1         0.065508           0.071475
# 2   3   6      0      0.1       1         0.152653           0.166559
# 3   4   8      1      0.1       1         0.065508           0.071475
# 4   5   1      0      0.1       0         0.065508           0.071475
# 5   6   9      1      0.1       1         0.065508           0.071475
# 6   6   5      0      0.1       1         0.152653           0.166559
# 7   7   8      1      0.1       1         0.065508           0.071475
# 8   9   9      0      0.1       1         0.152653           0.166559
# 9   9   2      0      0.1       0         0.065508           0.071475

# %%
df['nomalized_weights'].sum()
df['cumsum_upper'] = np.cumsum(df['nomalized_weights'])
df['cumsum_lower'] = df['cumsum_upper'] - df['nomalized_weights']
df[['X1','X2','label','weights','y_pred','updated_weights','cumsum_lower','cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  cumsum_lower  cumsum_upper
# 0   1   5      1      0.1       1         0.065508      0.000000      0.071475
# 1   2   3      1      0.1       1         0.065508      0.071475      0.142950
# 2   3   6      0      0.1       1         0.152653      0.142950      0.309508
# 3   4   8      1      0.1       1         0.065508      0.309508      0.380983
# 4   5   1      0      0.1       0         0.065508      0.380983      0.452458
# 5   6   9      1      0.1       1         0.065508      0.452458      0.523933
# 6   6   5      0      0.1       1         0.152653      0.523933      0.690492
# 7   7   8      1      0.1       1         0.065508      0.690492      0.761967
# 8   9   9      0      0.1       1         0.152653      0.761967      0.928525
# 9   9   2      0      0.1       0         0.065508      0.928525      1.000000

# %%
def create_new_dataset(df):

  indices = []

  for i in range(df.shape[0]):
    a = np.random.random()
    for index,row in df.iterrows():
      if row['cumsum_upper'] > a and a > row['cumsum_lower']:
        indices.append(index)
  return indices
index_values = create_new_dataset(df)
index_values
second_df = df.iloc[index_values,[0,1,2,3]]
second_df
# Out:
#    X1  X2  label  weights
# 5   6   9      1      0.1
# 8   9   9      0      0.1
# 5   6   9      1      0.1
# 2   3   6      0      0.1
# 4   5   1      0      0.1
# 6   6   5      0      0.1
# 5   6   9      1      0.1
# 0   1   5      1      0.1
# 5   6   9      1      0.1
# 2   3   6      0      0.1

# %%
dt2 = DecisionTreeClassifier(max_depth=1)
     
X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values
     
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 7.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf=dt2, legend=2)
# Out:
# <Axes: >

# %%
second_df['y_pred'] = dt2.predict(X)
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 5   6   9      1      0.1       1
# 8   9   9      0      0.1       1
# 5   6   9      1      0.1       1
# 2   3   6      0      0.1       0
# 4   5   1      0      0.1       0
# 6   6   5      0      0.1       0
# 5   6   9      1      0.1       1
# 0   1   5      1      0.1       0
# 5   6   9      1      0.1       1
# 2   3   6      0      0.1       0

# %%
alpha2 = calculate_model_weight(0.1)
alpha2
# Out:
# np.float64(1.0986122886681098)

# %%
# Step 4 - Update weights
def update_row_weights(row,alpha=1.09):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)
     
second_df['updated_weights'] = second_df.apply(update_row_weights,axis=1)
     
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 5   6   9      1      0.1       1         0.033622
# 8   9   9      0      0.1       1         0.297427
# 5   6   9      1      0.1       1         0.033622
# 2   3   6      0      0.1       0         0.033622
# 4   5   1      0      0.1       0         0.033622
# 6   6   5      0      0.1       0         0.033622
# 5   6   9      1      0.1       1         0.033622
# 0   1   5      1      0.1       0         0.297427
# 5   6   9      1      0.1       1         0.033622
# 2   3   6      0      0.1       0         0.033622
