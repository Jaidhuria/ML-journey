# %% [markdown]
# # Text-Preprocessing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # importing Dataset

# %%
df = pd.read_excel(r"C:\Users\jaidh\Downloads\archive (9)\nlpdataset\nlpdataset\labelled sentences(1).xlsx")
print(df.head(7))
# Out:
#                                            Sentences  Label
# 0  UN Humanitarian Chief Mark Lowcock today relea...      1
# 1  The announcement came as the World Health Orga...      0
# 2  The WHO has said there is still a chance of co...      1
# 3  There are now cases linked to Iran in Bahrain,...      1
# 4  Extensive testing in clinical trials has confi...      1
# 5  Modeling studies suggests that, if introduced ...      0
# 6  The Malaria Vaccine Implementation Programme (...      1

# %% [markdown]
# # To lowercase()

# %%
df['Sentences'][3].lower()
# Out:
# 'there are now cases linked to iran in bahrain, iraq, kuwait and oman, along with cases linked to italy in algeria, austria, croatia, germany, spain and switzerland.'

# %%
df['Sentences']=df["Sentences"].str.lower()

# %%
df
# Out:
#                                              Sentences  Label
# 0    un humanitarian chief mark lowcock today relea...      1
# 1    the announcement came as the world health orga...      0
# 2    the who has said there is still a chance of co...      1
# 3    there are now cases linked to iran in bahrain,...      1
# 4    extensive testing in clinical trials has confi...      1
# ..                                                 ...    ...
# 684  in november 2021, one stringent regulatory aut...      1
# 685  trials in children as young as age 3 years wer...      1
# 686  covaxin, an adjuvanted inactivated vaccine dev...      1
# 687  the indian regulatory authorities have given a...      1
# 688  several covid-19 vaccines are undergoing trial...      1
#
# [689 rows x 2 columns]

# %% [markdown]
# # Removal of html tag

# %%
import re

# %%
def def_tag(Sentences):
    pattern = re.compile(r'<.*?>')
    return pattern.sub(r'', Sentences)

# %%
Sentences = df.Sentences[234]

# %%
def_tag(Sentences)
# Out:
# 'yet, relatively few people around the world have access to quality services.'

# %% [markdown]
# # Remove Url

# %%
import re

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', Sentences)

# %%
remove_url(Sentences)
# Out:
# 'yet, relatively few people around the world have access to quality services.'

# %%
Sentences = 'Check out my notebook https://www.kaggle.com/avk/noteboor8rrswffc1abb'

# %%
remove_url(Sentences)
# Out:
# 'Check out my notebook '

# %% [markdown]
# # Removing puntuations

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc(Sentences):
    for char in exclude:
        Sentences = Sentences.replace(char, '')
    return Sentences

# %%
 Sentences = df.Sentences[640]

# %%
remove_punc(Sentences)
# Out:
# 'it will take a lot of hard work and itƒs going to take some time'

# %% [markdown]
# # Chat word treatment

# %%
def chat_conversion(Sentences):
    new_text = []

    for w in Sentences.split():
        if w.upper() in chat_words:
            new_text.append(chat_words[w.upper()])
        else:
            new_text.append(w)

    return " ".join(new_text)

# %%
chat_words = {
    "IMHO": "In My Honest Opinion",
    "LOL": "Laughing Out Loud",
    "OMG": "Oh My God",
    "BRB": "Be Right Back",
    "IDK": "I Don't Know"
}

# %%
chat_conversion('IMHO he is the best')
# Out:
# 'In My Honest Opinion he is the best'

# %% [markdown]
# # Removing Stop Words

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('spanish')
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %%
def remove_stopwords(Sentences):
    new_text = []

    for word in Sentences.split():
        if word.lower() not in stopwords.words('english'):
            new_text.append(word)

    return " ".join(new_text)

# %%
remove_stopwords('I love machine learning')
# Out:
# 'love machine learning'

# %% [markdown]
# # Tokenization

# %%
sent1 = 'I am going to delhi'
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
sent2 = 'I am going to delhi. I will stay there for 3 days. Let\'s hope the trip to be great'
sent2.split('.')
# Out:
# ['I am going to delhi',
#  ' I will stay there for 3 days',
#  " Let's hope the trip to be great"]

# %%
# Problems with split function
sent3 = 'I am going to delhi!'
sent3.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi!']

# %%
count = len(sent3)
print(count)
# Out:
# 20

# %%
sent4 = 'Where do think I should go? I have 3 day holiday'
sent4.split('.')
# Out:
# ['Where do think I should go? I have 3 day holiday']

# %% [markdown]
# # Regular Expression Tokenization

# %%
import re

# %%
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %% [markdown]
# # NLTK Tokenization

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
# we can use word_tokenizer for breaking text into words
sent1 = 'I am going to visit delhi!'
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'visit', 'delhi', '!']

# %%
# we use sent_tokenizer to break paragraph into sentences
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry? 
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, 
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, \nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %% [markdown]
# # Spacy

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------- ------------------ 6.8/12.8 MB 44.3 MB/s eta 0:00:01
#      ------------------------------------- - 12.3/12.8 MB 33.1 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 29.5 MB/s eta 0:00:00
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\jaidh\build\Lib\site-packages)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent1)

# %%
doc1
# Out:
# I am going to visit delhi!

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer
#porter stemmer for english 
#snawball stemmer for other language

# %%
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks baking walked"
stem_words(sample)
# Out:
# 'walk walk bake walk'

# %% [markdown]
# # lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

sentence = df.Sentences[243]
punctuations="?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)

sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print ("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# we                  we
# must                must
# better              better
# prepare             prepare
# for                 for
# emergencies         emergencies
# but                 but
# also                also
# keep                keep
# investing           invest
# in                  in
# health              health
# systems             systems
# that                that
# fully               fully
# respond             respond
# to                  to
# peopleƒ             peopleƒ
# ?                   ?
# s                   s
# needs               need
# throughout          throughout
# the                 the
# life                life
# course              course
